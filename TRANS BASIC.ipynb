# %%
#Πίνακας δεδομένων 
import pandas as pd
df = pd.read_csv('Untitled spreadsheet - tabula-TvT_TMM_TDoR2021_Namelist.csv')
df.columns=df.iloc[0]
df
# Out:
# 0                                              Name  Age     Occupa+on  \
# 0                                              Name  Age     Occupa+on
# 1     Nathalia\nLe+cia Barbosa\nda Fonseca\n(“Bia")   26  not reported
# 2                        Gretell\nCeballos\nRamírez   35  not reported
# 3                                    Felycya Harris   33  not reported
# 4               Michelle\nRamos Alarcón\n("Brenda")   26  not reported
# ...                                             ...  ...           ...
# 7511                                            NaN  NaN           NaN
# 7512                                            NaN  NaN           NaN
# 7513                                            NaN  NaN           NaN
# 7514                                            NaN  NaN           NaN
# 7515                                            NaN  NaN           NaN
#
# 0     Date of death       City   Country                   Loca+on of death  \
# ...

# %%
#Δολοφονίες trans α΄τομων στις Η.Π.Α
countries = df[df.Country=='USA']
countries.head()
# Out:
# 0              Name Age     Occupa+on Date of death          City Country  \
# 3    Felycya Harris  33  not reported    03/10/2020       Augusta     USA
# 31         DeShauna  20  not reported    07/10/2020    Shreveport     USA
# 84         DeShauna  20  not reported    07/10/2020    Shreveport     USA
# 147       Blackwood  29     bartender    11/10/2020  Indianapolis     USA
# 197       Blackwood  29     bartender    11/10/2020  Indianapolis     USA
#
# 0                     Loca+on of death Cause of death  \
# 3    park/public square/\nspace/market           shot
# 31                       own residence           shot
# 84                       own residence           shot
# 147                             street           shot
# 197                             street           shot
#
# 0                                              Remarks  \
# 3    Felycya's body was found in a park\nnext to an...
# 31                        Louisiana apartment complex.
# ...

# %%
#Δολοφονίες trans α΄τομων στην Βραζιλία
countries = df[df.Country=='Brazil']
countries.head()
# Out:
# 0                                            Name Age           Occupa+on  \
# 1   Nathalia\nLe+cia Barbosa\nda Fonseca\n(“Bia")  26        not reported
# 9                                    Paolla Bueno  17        not reported
# 15                                          Paris  42  stylist/beautician
# 62                                   Paolla Bueno  17        not reported
# 68                                          Paris  42  stylist/beautician
#
# 0  Date of death       City Country Loca+on of death Cause of death  \
# 1     03/10/2020     Paraná  Brazil    own residence           shot
# 9     05/10/2020  São Paulo  Brazil    own residence        stabbed
# 15    07/10/2020     Recife  Brazil     beauty salon           shot
# 62    05/10/2020  São Paulo  Brazil    own residence        stabbed
# 68    07/10/2020     Recife  Brazil     beauty salon           shot
#
# 0                                             Remarks  \
# ...

# %%
#Δολοφονίες trans α΄τομων στην Ελλάδα
countries = df[df.Country=='Greece']
countries.head()
# Out:
# 0            Name Age     Occupa+on Date of death    City Country  \
# 4241  Kalogiannis  64  not reported    09/04/2021  Athens  Greece
# 4309  Kalogiannis  64  not reported    09/04/2021  Athens  Greece
#
# 0    Loca+on of death   Cause of death                     Remarks  \
# 4241           street  run-over by car  later when the police were
# 4309           street  run-over by car  later when the police were
#
# 0                      Observaciones  \
# 4241  policía tuvo que ser instada a
# 4309  policía tuvo que ser instada a
#
# 0                                               Sources NaN  NaN  NaN
# 4241  dimitra-kalogiannis_athens-attica-greece_bf37bf57 NaN  NaN  NaN
# 4309  dimitra-kalogiannis_athens-attica-greece_bf37bf57 NaN  NaN  NaN

# %%
#Δολοφονίες trans α΄τομων στο Μαλάουι 
countries = df[df.Country=='Malawi']
countries.head()
# Out:
# 0             Name  Age     Occupa+on Date of death City Country  \
# 6039  Grace Mahoro  not  not reported    03/07/2021  NaN  Malawi
# 6107  Grace Mahoro  not  not reported    03/07/2021  NaN  Malawi
#
# 0    Loca+on of death Cause of death                           Remarks  \
# 6039     not reported         beaten  by news outlets and we know very
# 6107     not reported         beaten  by news outlets and we know very
#
# 0                   Observaciones Sources NaN  NaN  NaN
# 6039  informado por los medios de     NaN NaN  NaN  NaN
# 6107  informado por los medios de     NaN NaN  NaN  NaN

# %%
#Δολοφονίες trans α΄τομων στο Καζακστάν
countries = df[df.Country=='Kazakhstan']
countries.head()
# Out:
# 0          Name  Age     Occupa+on Date of death        City     Country  \
# 5896  Dzhakonda  not  not reported    21/06/2021  Nur-Sultan  Kazakhstan
# 5951  Dzhakonda  not  not reported    21/06/2021  Nur-Sultan  Kazakhstan
#
# 0        Loca+on of death Cause of death                            Remarks  \
# 5896  park/public square/        stabbed  incision was more than 15 cm, and
# 5951  park/public square/        stabbed  incision was more than 15 cm, and
#
# 0                    Observaciones                            Sources NaN  \
# 5896  más de 15 cm, y el corte era  TvT partner organisation: Alma-TQ NaN
# 5951  más de 15 cm, y el corte era  TvT partner organisation: Alma-TQ NaN
#
# 0     NaN  NaN
# 5896  NaN  NaN
# 5951  NaN  NaN

# %%
#Δολοφονίες ανηλίκων trans α΄τομων
ages = df[df.Age<'18']
ages.head()
# Out:
# 0              Name Age     Occupa+on Date of death               City  \
# 7            Marcos  17  not reported    04/10/2020  Ciudad De\nMexico
# 9      Paolla Bueno  17  not reported    05/10/2020          São Paulo
# 62     Paolla Bueno  17  not reported    05/10/2020          São Paulo
# 874  Paquita Brasil  17    sex worker    17/11/2020             Manaus
# 927  Paquita Brasil  17    sex worker    17/11/2020             Manaus
#
# 0   Country    Loca+on of death Cause of death  \
# 7    Mexico       own residence        stabbed
# 9    Brazil       own residence        stabbed
# 62   Brazil       own residence        stabbed
# 874  Brazil  beach/shore/river/          smoke
# 927  Brazil  beach/shore/river/          smoke
#
# 0                                              Remarks  \
# 7    Marcos was stabbed during an\nargument with hi...
# 9                      brother and her stepmother from
# 62                     brother and her stepmother from
# ...
